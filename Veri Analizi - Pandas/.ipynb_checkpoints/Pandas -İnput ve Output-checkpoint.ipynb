# %% [markdown]
# ## Çeşitli Dosya Tiplerini indirme ve kaydetme

# %% [markdown]
# ### 1.csv dosyaları

# %%
import pandas as pd

# %%
d =pd.read_csv("https://data.cdc.gov/api/views/bi63-dtpu/rows.csv")  #internetten csv indirme
d
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
d["State"].tolist()  #sutunu listeye çevirme
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Alaska',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
# ...

# %%
state= d["State"].to_frame()
state
# Out:
#                       State
# 0                   Alabama
# 1                    Alaska
# 2                   Arizona
# 3                  Arkansas
# 4                California
# 5                  Colorado
# 6               Connecticut
# 7                  Delaware
# 8      District of Columbia
# 9                   Florida
# 10                  Georgia
# 11                   Hawaii
# 12                    Idaho
# 13                 Illinois
# 14                  Indiana
# 15                     Iowa
# 16                   Kansas
# 17                 Kentucky
# 18                Louisiana
# 19                    Maine
# 20                 Maryland
# 21            Massachusetts
# 22                 Michigan
# 23                Minnesota
# 24              Mississippi
# 25                 Missouri
# 26                  Montana
# 27                 Nebraska
# 28                   Nevada
# 29            New Hampshire
# ...                     ...
# 10266             Wisconsin
# ...

# %%
state.to_csv("state.csv",index=False)  #data frame'i csv olarak kaydetme
#index'li şekilde kaydettiğimiz için 2 tane index oldu, bunu önlemek için index=False dedik

# %%
pd.read_csv("state.csv")
# Out:
#                       State
# 0                   Alabama
# 1                    Alaska
# 2                   Arizona
# 3                  Arkansas
# 4                California
# 5                  Colorado
# 6               Connecticut
# 7                  Delaware
# 8      District of Columbia
# 9                   Florida
# 10                  Georgia
# 11                   Hawaii
# 12                    Idaho
# 13                 Illinois
# 14                  Indiana
# 15                     Iowa
# 16                   Kansas
# 17                 Kentucky
# 18                Louisiana
# 19                    Maine
# 20                 Maryland
# 21            Massachusetts
# 22                 Michigan
# 23                Minnesota
# 24              Mississippi
# 25                 Missouri
# 26                  Montana
# 27                 Nebraska
# 28                   Nevada
# 29            New Hampshire
# ...                     ...
# 10266             Wisconsin
# ...

# %%
pd.read_excel("excel.xlsx")
# Out:
#           Futbolcu  Gol
# 0   Miroslav Klose    5
# 1   Lucas Podolski    4
# 2      David Villa    3
# 3   Maxi Rodriguez    3
# 4    Thierry Henry    3
# 5  Zinedine Zidane    3
# 6    Hernan Crespo    3
# 7  Fernando Torres    3
# 8          Ronaldo    3
# 9         Adriano     2

# %%
c=pd.read_excel("excel.xlsx",sheet_name=["2006","2010"])  #bütün sheetleri görmek için--> sheet_name
c
# Out:
# OrderedDict([('2006',           Futbolcu  Gol
#               0   Miroslav Klose    5
#               1   Lucas Podolski    4
#               2      David Villa    3
#               3   Maxi Rodriguez    3
#               4    Thierry Henry    3
#               5  Zinedine Zidane    3
#               6    Hernan Crespo    3
#               7  Fernando Torres    3
#               8          Ronaldo    3
#               9         Adriano     2), ('2010',           Futbolcu  Gol
#               0      David Villa    5
#               1  Wesley Sneijder    5
#               2     Diego Forlan    5
#               3    Thomas Müller    5
#               4   Miroslav Klose    4
#               5    Robert Vittek    4
#               6        G.Higuain    4
#               7     Asamoah Gyan    3
#               8   Landon Donovan    3
#               9      Luis Suares    3)])

# %%
c["2006"] #sadece 2006 sheet'ini görmek için
# Out:
#           Futbolcu  Gol
# 0   Miroslav Klose    5
# 1   Lucas Podolski    4
# 2      David Villa    3
# 3   Maxi Rodriguez    3
# 4    Thierry Henry    3
# 5  Zinedine Zidane    3
# 6    Hernan Crespo    3
# 7  Fernando Torres    3
# 8          Ronaldo    3
# 9         Adriano     2

# %%
dort=pd.read_csv("2014 wc.csv")
dort
# Out:
#           Futbolcu  Gol
# 0  James Rodriguez    6
# 1    Thomas Müller    5
# 2           Neymar    4
# 3     R.Van Persie    4
# 4     Lionel Messi    4
# 5   Andre Schürrle    3
# 6   Enner Valencia    3
# 7          Shakiri    3
# 8     Arjen Robben    3
# 9       Tim Cahill    2

# %%
dort.to_excel("214.xlsx",sheet_name="2014")  #csv'yi excele çevirme

# %%
b=pd.read_html("https://ipfs.io/ipfs/QmXoypizjW3WknFiJnKLwHCnL72vedxjQkDDP1mXWo6uco/wiki/List_of_banks_in_Turkey.html")
b  #Html dosyalarını okuma
# Out:
# [                                       0           1  \
#  0                                   Bank  Foundation
#  1                         Ziraat Bankası        1863
#  2                     Türkiye İş Bankası        1924
#  3                           Garanti Bank        1946
#  4                                 Akbank        1948
#  5                  Yapı ve Kredi Bankası        1944
#  6                           Halk Bankası        1938
#  7                              VakıfBank        1954
#  8                             Finansbank        1987
#  9                   Türk Ekonomi Bankası        1927
#  10                             Denizbank        1997
#  11                             HSBC Bank        1990
#  12                              ING Bank        1984
#  13                         Türk Eximbank        1987
#  14                              Odeabank        2012
#  15                             Şekerbank        1953
# ...

# %%
b[0] #0. indexi düzgün bir dataframe içeriyor
# Out:
#                                        0           1  \
# 0                                   Bank  Foundation
# 1                         Ziraat Bankası        1863
# 2                     Türkiye İş Bankası        1924
# 3                           Garanti Bank        1946
# 4                                 Akbank        1948
# 5                  Yapı ve Kredi Bankası        1944
# 6                           Halk Bankası        1938
# 7                              VakıfBank        1954
# 8                             Finansbank        1987
# 9                   Türk Ekonomi Bankası        1927
# 10                             Denizbank        1997
# 11                             HSBC Bank        1990
# 12                              ING Bank        1984
# 13                         Türk Eximbank        1987
# 14                              Odeabank        2012
# 15                             Şekerbank        1953
# 16                         İller Bankası        1933
# ...
