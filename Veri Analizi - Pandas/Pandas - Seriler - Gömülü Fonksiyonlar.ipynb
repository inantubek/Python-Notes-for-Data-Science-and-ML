# %% [markdown]
# ## Gömülü Fonksiyonlar (built in functions)

# %%
import pandas as pd

# %% [markdown]
# Tab tuşuna basarak otomatik tamamlamayı kullanabiliriz.

# %%
ulke=pd.read_csv("ulke.csv",squeeze=True)
gelir=pd.read_csv("milligelir.csv",squeeze=True)

# %%
len(ulke)
# Out:
# 73

# %%
type(ulke)
# Out:
# pandas.core.series.Series

# %%
sorted(ulke)
# Out:
# ['AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'AUSTRALIA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'CHINA',
#  'FRANCE',
#  'GERMANY',
#  'HONG KONG',
#  'HONG KONG',
#  'HONG KONG',
#  'INDIA',
#  'INDIA',
#  'INDIA',
#  'INDIA',
#  'ITALY',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'JAPAN',
#  'MALAYSIA',
#  'PHILIPPINES',
#  'REPUBLIC OF KOREA',
#  'REPUBLIC OF KOREA',
#  'REPUBLIC OF KOREA',
#  'REPUBLIC OF KOREA',
#  'REPUBLIC OF KOREA',
#  'REPUBLIC OF KOREA',
#  'SWEDEN',
#  'TAIWAN',
#  'TAIWAN',
#  'TAIWAN',
#  'THAILAND',
#  'THAILAND',
#  'THAILAND',
#  'THAILAND',
#  'THAILAND',
#  'THAILAND',
# ...

# %%
sorted(gelir)
# Out:
# [52999.92,
#  52999.92,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.0,
#  53000.04,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53004.0,
#  53250.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54075.0,
#  54250.0,
#  54254.0,
#  55000.0,
#  56379.0,
#  56754.0,
#  58000.0,
#  58004.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  65000.0,
# ...

# %%
list(ulke)
# Out:
# ['AUSTRALIA',
#  'CHINA',
#  'AUSTRALIA',
#  'CHINA',
#  'JAPAN',
#  'CHINA',
#  'JAPAN',
#  'THAILAND',
#  'CHINA',
#  'AUSTRALIA',
#  'CHINA',
#  'JAPAN',
#  'THAILAND',
#  'CHINA',
#  'AUSTRALIA',
#  'CHINA',
#  'THAILAND',
#  'CHINA',
#  'AUSTRALIA',
#  'CHINA',
#  'THAILAND',
#  'JAPAN',
#  'INDIA',
#  'CHINA',
#  'MALAYSIA',
#  'CHINA',
#  'AUSTRALIA',
#  'CHINA',
#  'THAILAND',
#  'REPUBLIC OF KOREA',
#  'CHINA',
#  'REPUBLIC OF KOREA',
#  'THAILAND',
#  'JAPAN',
#  'INDIA',
#  'CHINA',
#  'HONG KONG',
#  'JAPAN',
#  'TAIWAN',
#  'HONG KONG',
#  'PHILIPPINES',
#  'INDIA',
#  'AUSTRALIA',
#  'CHINA',
#  'THAILAND',
#  'CHINA',
#  'VIET NAM',
#  'CHINA',
#  'HONG KONG',
#  'JAPAN',
#  'CHINA',
#  'JAPAN',
#  'CHINA',
#  'REPUBLIC OF KOREA',
#  'JAPAN',
#  'CHINA',
#  'AUSTRALIA',
#  'TAIWAN',
#  'REPUBLIC OF KOREA',
#  'AUSTRALIA',
#  'THAILAND',
#  'CHINA',
#  'INDIA',
#  'CHINA',
#  'TAIWAN',
#  'REPUBLIC OF KOREA',
#  'CHINA',
#  'REPUBLIC OF KOREA',
#  'AUSTRALIA',
# ...

# %%
list(gelir)
# Out:
# [65625.0,
#  150000.0,
#  106573.89,
#  77400.0,
#  725000.0,
#  150000.0,
#  285008.0,
#  74000.0,
#  93750.0,
#  66150.0,
#  413333.33,
#  77004.0,
#  164250.0,
#  175008.0,
#  85008.0,
#  1041310.0,
#  568000.0,
#  183756.0,
#  53000.0,
#  325008.0,
#  165300.0,
#  65004.0,
#  195000.04,
#  279500.0,
#  65004.0,
#  120008.0,
#  770750.0,
#  53004.0,
#  53004.0,
#  65000.0,
#  820937.5,
#  142500.0,
#  178850.0,
#  65004.0,
#  54075.0,
#  109875.0,
#  53004.0,
#  65625.0,
#  564212.5,
#  65004.0,
#  65000.0,
#  87000.0,
#  233333.33,
#  135000.0,
#  65004.0,
#  716674.67,
#  570000.0,
#  81375.0,
#  500000.0,
#  165000.0,
#  80000.04,
#  1906333.37,
#  114900.0,
#  267133.34,
#  5400000.0,
#  328312.42,
#  118125.0,
#  171250.0,
#  72500.04,
#  296666.67,
#  84996.0,
#  99879.0,
#  175000.0,
#  290000.0,
#  251875.0,
#  72500.04,
#  1050000.0,
#  54075.0,
#  92500.0,
#  150000.0,
#  482500.0,
#  53004.0,
#  53004.0,
#  168375.0,
#  70133.4,
#  844000.0,
#  328750.0,
#  242500.0,
# ...

# %%
dict(gelir)
# Out:
# {0: 65625.0,
#  1: 150000.0,
#  2: 106573.89,
#  3: 77400.0,
#  4: 725000.0,
#  5: 150000.0,
#  6: 285008.0,
#  7: 74000.0,
#  8: 93750.0,
#  9: 66150.0,
#  10: 413333.33,
#  11: 77004.0,
#  12: 164250.0,
#  13: 175008.0,
#  14: 85008.0,
#  15: 1041310.0,
#  16: 568000.0,
#  17: 183756.0,
#  18: 53000.0,
#  19: 325008.0,
#  20: 165300.0,
#  21: 65004.0,
#  22: 195000.04,
#  23: 279500.0,
#  24: 65004.0,
#  25: 120008.0,
#  26: 770750.0,
#  27: 53004.0,
#  28: 53004.0,
#  29: 65000.0,
#  30: 820937.5,
#  31: 142500.0,
#  32: 178850.0,
#  33: 65004.0,
#  34: 54075.0,
#  35: 109875.0,
#  36: 53004.0,
#  37: 65625.0,
#  38: 564212.5,
#  39: 65004.0,
#  40: 65000.0,
#  41: 87000.0,
#  42: 233333.33,
#  43: 135000.0,
#  44: 65004.0,
#  45: 716674.67,
#  46: 570000.0,
#  47: 81375.0,
#  48: 500000.0,
#  49: 165000.0,
#  50: 80000.04,
#  51: 1906333.37,
#  52: 114900.0,
#  53: 267133.34,
#  54: 5400000.0,
#  55: 328312.42,
#  56: 118125.0,
#  57: 171250.0,
#  58: 72500.04,
#  59: 296666.67,
# ...

# %%
max(gelir)
# Out:
# 7167500.0

# %%
min(gelir)
# Out:
# 52999.92
